# %%
from __future__ import absolute_import, division, print_function
import tensorflow as tf

#%pip install keras-tcn --no-dependencies

#%pip install tensorflow-addons[tensorflow-gpu] --no-dependencies

#%pip install pandas --upgrade

#%pip install import multivariate_cwru


tf.config.list_physical_devices(device_type=None)
physical_devices = tf.config.list_physical_devices('GPU')
visible_devices = tf.config.get_visible_devices()
print(visible_devices)
num_GPU = len(tf.config.experimental.list_physical_devices('/physical_device:GPU:0'))
#if num_GPU == 1:
#tf.config.experimental.set_memory_growth(physical_devices[0], True)
#elif num_GPU == 2:
tf.config.experimental.set_memory_growth(physical_devices[1], True)
tf.config.experimental.set_memory_growth(physical_devices[0], True)
#elif num_GPU == 4:
    #tf.config.experimental.set_memory_growth(physical_devices[1], True)
    #tf.config.experimental.set_memory_growth(physical_devices[0], True)
    #tf.config.experimental.set_memory_growth(physical_devices[1], True)
    #tf.config.experimental.set_memory_growth(physical_devices[0], True)
#print("Num GPUs Available: ", num_GPU)
#tf.debugging.set_log_device_placement(False)
mirrored_strategy = tf.distribute.MirroredStrategy(devices=["/gpu:1"])
#strategy = tf.distribute.MirroredStrategy(
    #cross_device_ops=tf.distribute.HierarchicalCopyAllReduce())
# Data science libraries
import scipy.io
from scipy import stats
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn import metrics

#Deep Learning pkgs
from tensorflow.keras import backend as K, Input, Model, optimizers
from tensorflow.keras.layers import Dense, Activation
import tensorflow.keras.metrics
from tensorflow.keras.metrics import SparseCategoricalCrossentropy
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ReduceLROnPlateau, TensorBoard, ModelCheckpoint, Callback
from tensorflow.keras.activations import swish
K.backend()

# Python
from IPython.core.debugger import set_trace
from pathlib import Path
import os
import datetime
import time
import glob
from timeit import default_timer as timer


#Project Specific
import tcn_ed
from tcn_ed import TCN, tcn_full_summary, compiled_tcn
import help_matt_val
from help_matt_val import predict_batch, create_predict_frames#, create_data_batch, create_frames, sig_divide, matfile_to_df,  create_data_batch_notest, create_frames_notest
from help_pre import create_data_batcht as Create_Batch, create_pred_batch
import multivariate_cwru
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:1',)
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')

# %%
mirrored_strategy = tf.distribute.MirroredStrategy()
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')

# %% [raw]
# data1 = multivariate_cwru.CWRU("12DriveEndFault", 1000000, 1, 1,2,'1797',"1797","1772","1750","1730",normal_condition = True)
# data2 = multivariate_cwru.CWRU("12FanEndFault", 2400, 1, 1,2,'1797',"1797","1772","1750","1730",normal_condition = True)
# data3 = multivariate_cwru.CWRU("48DriveEndFault", 1000000, 1, 1,2,"1797",normal_condition = True)
# #data = multivariate_cwru.CWRU("48DriveEndFault", 2400, 0, 1,2,"1772",normal_condition = True) # Throws an error
# data4 = multivariate_cwru.CWRU("48DriveEndFault", 1000000, 1, 1,2,"1750",normal_condition = True)
# data5 = multivariate_cwru.CWRU("48DriveEndFault", 1000000, 1, 1,2,"1730",normal_condition = True)

# %%
os.getcwd()
# Out:
# '/home/ubuntu/upload_dir'

# %%
working_dir = Path('.')
DATA1_PATH = Path("./Datasets")
DATA_PATH = Path("./Datasets/CWRU")
save_model_path = working_dir / 'Model' 
DE_path = DATA_PATH / '12DriveEndFault'
DE_path1 = DE_path / '1730'
DE_path2 = DE_path / '1750'
DE_path3 = DE_path / '1772'
DE_path4 = DE_path / '1797'

FE_path = DATA_PATH / '12FanEndFault'
FE_path1 = FE_path / '1730'
FE_path2 = FE_path / '1750'
FE_path3 = FE_path / '1772'
FE_path4 = FE_path / '1797'

DE48_path = DATA_PATH / '48DriveEndFault'
DE48_path1 = DE48_path / '1730'
DE48_path2 = DE48_path / '1750'
DE48_path3 = DE48_path / '1772'
DE48_path4 = DE48_path / '1797'

Normal_path = DATA_PATH / 'NormalBaseline'
Normal_path1 = Normal_path / '1730'
Normal_path2 = Normal_path / '1750'
Normal_path3 = Normal_path / '1772'
Normal_path4 = Normal_path / '1797'

Paths = [DE_path1, DE_path2, DE_path3, DE_path4, FE_path1, FE_path2, FE_path3, FE_path4, DE48_path1, DE48_path2,  DE48_path4, Normal_path1, Normal_path2, Normal_path3, Normal_path4]
data_path = Paths

val_path = DATA1_PATH / 'for_pred'
Val_path= [val_path]



segment_length = 2400 # The length of the window used to take sub-arrays from each file
step_size = 300 # the amount the window moves along the sub-array
split_perc = 0.2 # percentage of data to put towards the test set
b_size = 1024
b_size1 = int(b_size*2)
#b_size2 = int(b_size / 4)

#step_length = step_size

for path in [DATA_PATH, save_model_path]:
    if not path.exists():
        path.mkdir(parents=True)
        
data_path = Paths

# %% [markdown]
# ```'N':0, 'B':1, 'IR':2, 'OR':3```

# %%
with mirrored_strategy.scope():
    
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', 
                                  factor=0.3,   
                                  patience=40, 
                                  min_lr=0.000000015,
                                  verbose=1, 
                                  cooldown=5)

    ES_cb = tf.keras.callbacks.EarlyStopping(monitor='val_loss', 
                                             min_delta=0.00001, 
                                             patience=70, 
                                             verbose=1, 
                                             mode='auto', 
                                             baseline=None, 
                                             restore_best_weights=True)



    callback = ES_cb

def adjust_dilations(dilations: list):
    if all([is_power_of_two(i) for i in dilations]):
        return dilations
    else:
        new_dilations = [2 ** i for i in dilations]
        return new_dilations
        
def pred_accuracy(y_true, y_pred):
            # reshape in case it's in shape (num_samples, 1) instead of (num_samples,)
            # convert dense predictions to labels
            y_pred_labels = K.cast(y_pred, K.floatx())
            return K.cast(K.equal(y_true, y_pred_labels), K.floatx())

def create_model(num_feat,
                 num_classes,
                 filt_num,
                 kernel_num,
                 stack, dilation,
                 lr,
                 drop_rate,
                 segment_length,
                 use_skip,
                 opt):

    with mirrored_strategy.scope():

        input_layer = Input(shape=(segment_length, num_feat))

        def get_opt():
            if opt == 'adam':
                return optimizers.Adam(lr=lr)
            elif opt == 'rmsprop':
                return optimizers.RMSprop(lr=lr)
            else:
                raise Exception('Only Adam and RMSProp are available here')
            
        x = TCN(nb_filters=filt_num,
                kernel_size=kernel_num,
                nb_stacks=stack,
                dilations=[2 ** i for i in range(dilation)],
                padding='causal',
                use_skip_connections=use_skip,
                dropout_rate=drop_rate,
                return_sequences=False,
                activation='swish', 
                kernel_initializer='he_uniform',
                use_batch_norm=False,
                use_layer_norm=False,
                use_weight_norm=True,
                name='Model')(input_layer)

        tcn = TCN(nb_filters=filt_num,
                  kernel_size=kernel_num,
                  nb_stacks=stack,
                  dilations=[2 ** i for i in range(dilation)],
                  padding='causal',
                  use_skip_connections=use_skip,
                  dropout_rate=drop_rate,
                  return_sequences=False,
                  activation='swish', 
                  kernel_initializer='he_uniform',
                  use_batch_norm=False,
                  use_layer_norm=False,
                  use_weight_norm=True,
                  name='Model')

        print('Receptive Field Size: %s' % tcn.receptive_field)



        print('x.shape=', x.shape)


        # classification
        x = Dense(num_classes)(x)
        x = Activation('softmax', dtype='float32')(x)
        output_layer = x
        model = Model(input_layer, output_layer)

        # https://github.com/keras-team/keras/pull/11373
        # It's now in Keras@master but still not available with pip.
        # TODO remove later.

    with mirrored_strategy.scope():
        model.compile(get_opt(), loss='sparse_categorical_crossentropy', metrics=['sparse_categorical_accuracy'])

        print('model.x = {}'.format(input_layer.shape))
        print('model.y = {}'.format(output_layer.shape))

        print('Filter Length: %s' % filt_num)
        print('Kernel Size: %s' % kernel_num)
        print('Dilation: %s' % dilation)
        print('Learning Rate: %s' % lr)
        print('Dropout Rate: %s' % drop_rate)

        model.summary()


        return model

def train_func(train_data,
               test_dataset,
               Val_dataset,
               predict_labels,
               segment_length,
               runs,
               filt_num,
               kernel_num,
               dilation,
               stack,
               learn_r,
               drop_rate,
               Model_num):
    
    
        
    time1 = timer()
        
    working_dir = Path('.')
    model_path = working_dir / 'Model' / ('Model_{}_k{}_s{}_di{}_dr{}_L{}'.format(Model_num, kernel_num, stack, dilation, drop_rate, segment_length))
    
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', 
                                  factor=0.3,   
                                  patience=70, 
                                  min_lr=0.000015,
                                  verbose=0, 
                                  cooldown=5)

    ES_cb = tf.keras.callbacks.EarlyStopping(monitor='val_loss', 
                                             min_delta=0.00001, 
                                             patience=70, 
                                             verbose=0, 
                                             mode='auto', 
                                             baseline=None, 
                                             restore_best_weights=True)
    

    # to load best weights model.load_weights(latest)

    callback = ES_cb# ] [reduce_lr, 
    #seg_length = None
    time_out = timer()-time1
    print('Time till start of create model %s' % time_out)
    time2 = timer()
    model = create_model(num_feat=1,
                         num_classes=4,
                         filt_num=filt_num,
                         kernel_num=kernel_num,
                         stack=stack,
                         dilation=dilation,
                         lr=learn_r,
                         drop_rate=drop_rate,
                         segment_length = segment_length,
                         use_skip=True,
                         opt='adam')

    time3 = timer()
    time_out = time3-time2
    print('Time to create model %s' % time_out)
    with mirrored_strategy.scope():
        history = model.fit(train_data,
                  epochs=runs,
                  verbose=2,
                  callbacks=callback,
                  validation_data=test_dataset)
    plt.plot(history.history['sparse_categorical_accuracy'])
    plt.show()
    plt.plot(history.history['loss'])
    plt.show()
    time_out = timer()-time3
    print('Time to fit model %s' % time_out)
    with mirrored_strategy.scope():
        y_preds = model.predict(Val_dataset,
                                       verbose=1,
                                       callbacks=callback,
                                      )
        y_argmax2 = np.argmax(y_preds,axis=1)
        predict_labels = np.squeeze(predict_labels[:], axis=1)
        #for pred1, pred2, pred3, pred4 in y_pred:
        #y_argmax = []
        #i=0
        perc_score = tf.dtypes.cast((sum(pred_accuracy(predict_labels, y_argmax2))/(len(predict_labels))), tf.float16)
        Accuracy_test = float(perc_score)
        print('Prediction Accuracy: %s' % Accuracy_test)
        con_mat = metrics.confusion_matrix(predict_labels, y_argmax2)
        class_report = metrics.classification_report(predict_labels, y_argmax2, digits=3)
        print(con_mat, '\n\n')
        print(class_report, '\n\n')
    
    

    
    d = {'segment length':[segment_length], 'filters': [filt_num], 'kernel size': [kernel_num], 'stacks':[stack], 'dropout': [drop_rate], 'lr': [learn_r], 'dilation': [dilation], 'Training Time': time_out, 'train loss': [history.history['loss'][-1]], 'train acc': [history.history['sparse_categorical_accuracy'][-1]], 'eval acc': [history.history['val_sparse_categorical_accuracy'][-1]], 'Eval Acc': [Accuracy_test],'C1 correct': [con_mat[0][0]], 'C1 as C2':[con_mat[0][1]], 'C1 as C3':[con_mat[0][2]], 'C1 as C4':[con_mat[0][3]],'C2 as C1': [con_mat[1][0]], 'C2 correct':[con_mat[1][1]], 'C2 as C3':[con_mat[1][2]], 'C2 as C4':[con_mat[1][3]],'C3 as C1': [con_mat[2][0]], 'C3 as C2':[con_mat[2][1]], 'C3 correct':[con_mat[2][2]], 'C3 as C4':[con_mat[2][3]],'C4 as C1': [con_mat[3][0]], 'C4 as C2':[con_mat[3][1]], 'C4 as C3':[con_mat[3][2]], 'C4 correct':[con_mat[3][3]]}
    
    
    append_list2_in = pd.DataFrame.from_dict(d)
    
    time_out = timer()-time1
    print('Total Time %s' % time_out)
    
    return history, y_preds, append_list2_in

def create_model2(num_feat,
                 num_classes,
                 filt_num,
                 kernel_num,
                 stack, dilation,
                 lr,
                 drop_rate,
                 segment_length,
                 use_skip,
                 opt):




    with mirrored_strategy.scope():
        #x =Sequential()

        
        input_layer = Input(shape=(segment_length, num_feat))

        def get_opt():
            if opt == 'adam':
                return optimizers.Adam(lr=lr)
            elif opt == 'rmsprop':
                return optimizers.RMSprop(lr=lr)
            else:
                raise Exception('Only Adam and RMSProp are available here')
            
        x = TCN(nb_filters=filt_num,
                kernel_size=kernel_num,
                nb_stacks=stack,
                dilations=[2 ** i for i in range(dilation)],
                padding='causal',
                use_skip_connections=use_skip,
                dropout_rate=drop_rate,
                return_sequences=False,
                activation='swish', 
                kernel_initializer='he_uniform',
                use_batch_norm=False,
                use_layer_norm=False,
                use_weight_norm=True,
                name='Model')(input_layer)

        tcn = TCN(nb_filters=filt_num,
                  kernel_size=kernel_num,
                  nb_stacks=stack,
                  dilations=[2 ** i for i in range(dilation)],
                  padding='causal',
                  use_skip_connections=use_skip,
                  dropout_rate=drop_rate,
                  return_sequences=False,
                  activation='swish', 
                  kernel_initializer='he_uniform',
                  use_batch_norm=True,
                  use_layer_norm=False,
                  use_weight_norm=False,
                  name='Model')

        print('Receptive Field Size: %s' % tcn.receptive_field)



        print('x.shape=', x.shape)


        # classification
        x = Dense(num_classes)(x)
        x = Activation('softmax', dtype='float32')(x)
        output_layer = x
        model = Model(input_layer, output_layer)

        # https://github.com/keras-team/keras/pull/11373
        # It's now in Keras@master but still not available with pip.
        # TODO remove later.

    with mirrored_strategy.scope():
        model.compile(get_opt(), loss='sparse_categorical_crossentropy', metrics=['sparse_categorical_accuracy'])

        print('model.x = {}'.format(input_layer.shape))
        print('model.y = {}'.format(output_layer.shape))

        print('Filter Length: %s' % filt_num)
        print('Kernel Size: %s' % kernel_num)
        print('Dilation: %s' % dilation)
        print('Learning Rate: %s' % lr)
        print('Dropout Rate: %s' % drop_rate)

        model.summary()


        return model

def train_func2(train_data,
               test_dataset,
               Val_dataset,
               predict_labels,
               segment_length,
               runs,
               filt_num,
               kernel_num,
               dilation,
               stack,
               learn_r,
               drop_rate,
               Model_num):
    
    
        
    time1 = timer()
        
    working_dir = Path('.')
    model_path = working_dir / 'Model' / ('Model_{}_k{}_s{}_di{}_dr{}_L{}.H5'.format(Model_num, kernel_num, stack, dilation, drop_rate, segment_length))
    
    

    #seg_length = None
    time_out = timer()-time1
    print('Time till start of create model %s' % time_out)
    time2 = timer()
    model = create_model(num_feat=1,
                         num_classes=4,
                         filt_num=filt_num,
                         kernel_num=kernel_num,
                         stack=stack,
                         dilation=dilation,
                         lr=learn_r,
                         drop_rate=drop_rate,
                         segment_length = segment_length,
                         use_skip=True,
                         opt='adam')

    time3 = timer()
    time_out = time3-time2
    print('Time to create model %s' % time_out)
    with mirrored_strategy.scope():
        history = model.fit(train_data,
                  epochs=runs,
                  verbose=2,
                  callbacks=callback,
                  validation_data=test_dataset)
    plt.plot(history.history['sparse_categorical_accuracy'])
    plt.show()
    plt.plot(history.history['loss'])
    plt.show()
    time_out = timer()-time3
    print('Time to fit model %s' % time_out)
    with mirrored_strategy.scope():
        y_preds = model.predict(Val_dataset,
                                       verbose=0,
                                       callbacks=callback,
                                      )
        y_argmax2 = np.argmax(y_preds,axis=1)
        predict_labels = np.squeeze(predict_labels[:], axis=1)
        #for pred1, pred2, pred3, pred4 in y_pred:
        #y_argmax = []
        #i=0
        perc_score = tf.dtypes.cast((sum(pred_accuracy(predict_labels, y_argmax2))/(len(predict_labels))), tf.float16)
        Accuracy_test = float(perc_score)
        print('Prediction Accuracy: %s' % Accuracy_test)
        con_mat = metrics.confusion_matrix(predict_labels, y_argmax2)
        class_report = metrics.classification_report(predict_labels, y_argmax2, digits=3)
        print(con_mat, '\n\n')
        print(class_report, '\n\n')
    
    

    
    d = {'segment length':[segment_length], 'filters': [filt_num], 'kernel size': [kernel_num], 'stacks':[stack], 'dropout': [drop_rate], 'lr': [learn_r], 'dilation': [dilation], 'Training Time': time_out, 'train loss': [history.history['loss'][-1]], 'train acc': [history.history['sparse_categorical_accuracy'][-1]], 'eval acc': [history.history['val_sparse_categorical_accuracy'][-1]], 'Eval Acc': [Accuracy_test],'C1 correct': [con_mat[0][0]], 'C1 as C2':[con_mat[0][1]], 'C1 as C3':[con_mat[0][2]], 'C1 as C4':[con_mat[0][3]],'C2 as C1': [con_mat[1][0]], 'C2 correct':[con_mat[1][1]], 'C2 as C3':[con_mat[1][2]], 'C2 as C4':[con_mat[1][3]],'C3 as C1': [con_mat[2][0]], 'C3 as C2':[con_mat[2][1]], 'C3 correct':[con_mat[2][2]], 'C3 as C4':[con_mat[2][3]],'C4 as C1': [con_mat[3][0]], 'C4 as C2':[con_mat[3][1]], 'C4 as C3':[con_mat[3][2]], 'C4 correct':[con_mat[3][3]]}
    
    
    append_list2_in = pd.DataFrame.from_dict(d)
       
    time_out = timer()-time1
    print('Total Time %s' % time_out)
    
    return model, history, y_preds, append_list2_in

# %%
b_size = 256 #normally 2048 but 512 on colab
b_size2 = int(b_size / 4)
step_size = 300
step_length=step_size
segment_length = 2400
with mirrored_strategy.scope():
    train_dataset, test_dataset, y_s1 = Create_Batch(data_path, split_perc, segment_length, step_length, b_size)
waste_split = 0.1
# Out:
# Sig Divide Time: 1.4880847930908203
# Sig Divide Time: 8.292505264282227

# %%
with mirrored_strategy.scope():
    val_dataset, X_v1, predict_labels= create_pred_batch(Val_path=Val_path, segment_length=segment_length, step_length=step_size, b_size=int(b_size/4))
# Out:
# Sig Divide Time: 1.0887839794158936

# %%
tf.keras.backend.clear_session()
b_size = 256 #normally 2048 but 512 on colab
b_size2 = int(b_size / 4)
step_size = 300
step_length=step_size
segment_length = 2400
#with mirrored_strategy.scope():
    #train_dataset, test_dataset, y_s1 = Create_Batch(data_path, split_perc, segment_length, step_length, b_size)
waste_split = 0.1
with mirrored_strategy.scope():
    
    #Tuned Param dropout
    Learning_Rate = 0.0125
    Drop_rate = 0.175
    Repeats = 75

    m_count = 1
    append_list_time1 = pd.DataFrame
    print('Model Number %s' % m_count)
    history, y_preds, res_list = train_func(train_data=train_dataset,
                                            test_dataset=test_dataset,
                                            Val_dataset=val_dataset,
                                            predict_labels=predict_labels, 
                                            filt_num=16,
                                            kernel_num=11,
                                            dilation=7,
                                            stack=1,
                                            learn_r=Learning_Rate,
                                            drop_rate=Drop_rate,
                                            runs=Repeats,
                                            Model_num = m_count, 
                                            segment_length = segment_length)
    append_list_time1 = append_list_time1.append(res_list, ignore_index=True)
    Learning_Rate = 0.0125
    Drop_rate = 0.3
    Repeats = 75

    m_count = 2
    print('Model Number %s' % m_count)
    history, y_preds, res_list = train_func(train_data=train_dataset,
                                            test_dataset=test_dataset,
                                            Val_dataset=val_dataset,
                                            predict_labels=predict_labels, 
                                            filt_num=16,
                                            kernel_num=11,
                                            dilation=7,
                                            stack=1,
                                            learn_r=Learning_Rate,
                                            drop_rate=Drop_rate,
                                            runs=Repeats,
                                            Model_num = m_count, 
                                            segment_length = segment_length)

    append_list_time1 = append_list_time1.append(res_list, ignore_index=True)
    tf.keras.backend.clear_session()
# Out:
# Model Number 1
# Time till start of create model 9.968000085791573e-05
# Receptive Field Size: 2541
# x.shape= (None, 16)
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# model.x = (None, 2400, 1)
# model.y = (None, 4)
# Filter Length: 16
# Kernel Size: 11
# Dilation: 7
# Learning Rate: 0.0125
# Dropout Rate: 0.175
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 2400, 1)]         0
# _________________________________________________________________
# Model (TCN)                  (None, 16)                74286
# _________________________________________________________________
# dense (Dense)                (None, 4)                 68
# _________________________________________________________________
# activation (Activation)      (None, 4)                 0
# =================================================================
# Total params: 74,354
# Trainable params: 37,332
# Non-trainable params: 37,022
# _________________________________________________________________
# Time to create model 1.7003729910011316
# Epoch 1/75
# INFO:tensorflow:batch_all_reduce: 46 all-reduces with algorithm = nccl, num_packs = 1
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:batch_all_reduce: 46 all-reduces with algorithm = nccl, num_packs = 1
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# 428/428 - 54s - loss: 0.7557 - sparse_categorical_accuracy: 0.6505 - val_loss: 0.4851 - val_sparse_categorical_accuracy: 0.7999
# Epoch 2/75
# 428/428 - 30s - loss: 0.3955 - sparse_categorical_accuracy: 0.8303 - val_loss: 0.5038 - val_sparse_categorical_accuracy: 0.7655
# Epoch 3/75
# 428/428 - 30s - loss: 0.2721 - sparse_categorical_accuracy: 0.8941 - val_loss: 0.4173 - val_sparse_categorical_accuracy: 0.8254
# Epoch 4/75
# 428/428 - 30s - loss: 0.2005 - sparse_categorical_accuracy: 0.9287 - val_loss: 0.7261 - val_sparse_categorical_accuracy: 0.9001
# Epoch 5/75
# 428/428 - 30s - loss: 0.1431 - sparse_categorical_accuracy: 0.9514 - val_loss: 1.0687 - val_sparse_categorical_accuracy: 0.8810
# Epoch 6/75
# 428/428 - 30s - loss: 0.1167 - sparse_categorical_accuracy: 0.9604 - val_loss: 1.8444 - val_sparse_categorical_accuracy: 0.8832
# Epoch 7/75
# 428/428 - 30s - loss: 0.1006 - sparse_categorical_accuracy: 0.9663 - val_loss: 3.6169 - val_sparse_categorical_accuracy: 0.8969
# Epoch 8/75
# 428/428 - 31s - loss: 0.0917 - sparse_categorical_accuracy: 0.9694 - val_loss: 3.7076 - val_sparse_categorical_accuracy: 0.9135
# Epoch 9/75
# 428/428 - 31s - loss: 0.0790 - sparse_categorical_accuracy: 0.9738 - val_loss: 2.7555 - val_sparse_categorical_accuracy: 0.8902
# Epoch 10/75
# 428/428 - 46s - loss: 0.0711 - sparse_categorical_accuracy: 0.9770 - val_loss: 3.0876 - val_sparse_categorical_accuracy: 0.9103
# Epoch 11/75
# 428/428 - 63s - loss: 0.0656 - sparse_categorical_accuracy: 0.9788 - val_loss: 2.2434 - val_sparse_categorical_accuracy: 0.8925
# Epoch 12/75
# 428/428 - 67s - loss: 0.0620 - sparse_categorical_accuracy: 0.9798 - val_loss: 2.5158 - val_sparse_categorical_accuracy: 0.8967
# Epoch 13/75
# 428/428 - 66s - loss: 0.0613 - sparse_categorical_accuracy: 0.9804 - val_loss: 2.7602 - val_sparse_categorical_accuracy: 0.9044
# Epoch 14/75
# 428/428 - 67s - loss: 0.0552 - sparse_categorical_accuracy: 0.9820 - val_loss: 2.3339 - val_sparse_categorical_accuracy: 0.8768
# Epoch 15/75
# 428/428 - 67s - loss: 0.0502 - sparse_categorical_accuracy: 0.9843 - val_loss: 3.5223 - val_sparse_categorical_accuracy: 0.9087
# Epoch 16/75
# 428/428 - 68s - loss: 0.0485 - sparse_categorical_accuracy: 0.9846 - val_loss: 2.0006 - val_sparse_categorical_accuracy: 0.9099
# Epoch 17/75
# 428/428 - 66s - loss: 0.0500 - sparse_categorical_accuracy: 0.9841 - val_loss: 1.8033 - val_sparse_categorical_accuracy: 0.9107
# Epoch 18/75
# 428/428 - 67s - loss: 0.0421 - sparse_categorical_accuracy: 0.9866 - val_loss: 3.2416 - val_sparse_categorical_accuracy: 0.8952
# Epoch 19/75
# 428/428 - 68s - loss: 0.0443 - sparse_categorical_accuracy: 0.9860 - val_loss: 3.7871 - val_sparse_categorical_accuracy: 0.9144
# Epoch 20/75
# 428/428 - 67s - loss: 0.0463 - sparse_categorical_accuracy: 0.9851 - val_loss: 2.3711 - val_sparse_categorical_accuracy: 0.8975
# Epoch 21/75
# 428/428 - 66s - loss: 0.0405 - sparse_categorical_accuracy: 0.9876 - val_loss: 2.3078 - val_sparse_categorical_accuracy: 0.9100
# Epoch 22/75
# 428/428 - 67s - loss: 0.0399 - sparse_categorical_accuracy: 0.9871 - val_loss: 3.0610 - val_sparse_categorical_accuracy: 0.9179
# Epoch 23/75
# 428/428 - 67s - loss: 0.0390 - sparse_categorical_accuracy: 0.9881 - val_loss: 3.1417 - val_sparse_categorical_accuracy: 0.9194
# Epoch 24/75
# 428/428 - 67s - loss: 0.0366 - sparse_categorical_accuracy: 0.9884 - val_loss: 2.1827 - val_sparse_categorical_accuracy: 0.9173
# Epoch 25/75
# 428/428 - 67s - loss: 0.0381 - sparse_categorical_accuracy: 0.9882 - val_loss: 3.4934 - val_sparse_categorical_accuracy: 0.9079
# Epoch 26/75
# 428/428 - 67s - loss: 0.0350 - sparse_categorical_accuracy: 0.9891 - val_loss: 2.8203 - val_sparse_categorical_accuracy: 0.8895
# Epoch 27/75
# 428/428 - 67s - loss: 0.0327 - sparse_categorical_accuracy: 0.9897 - val_loss: 2.4573 - val_sparse_categorical_accuracy: 0.9221
# Epoch 28/75
# 428/428 - 67s - loss: 0.0342 - sparse_categorical_accuracy: 0.9892 - val_loss: 3.6360 - val_sparse_categorical_accuracy: 0.9084
# Epoch 29/75
# 428/428 - 67s - loss: 0.0326 - sparse_categorical_accuracy: 0.9898 - val_loss: 2.1595 - val_sparse_categorical_accuracy: 0.8989
# Epoch 30/75
# 428/428 - 67s - loss: 0.0366 - sparse_categorical_accuracy: 0.9890 - val_loss: 3.2846 - val_sparse_categorical_accuracy: 0.8941
# Epoch 31/75
# 428/428 - 68s - loss: 0.0344 - sparse_categorical_accuracy: 0.9888 - val_loss: 3.9608 - val_sparse_categorical_accuracy: 0.9219
# Epoch 32/75
# 428/428 - 66s - loss: 0.0302 - sparse_categorical_accuracy: 0.9905 - val_loss: 4.3420 - val_sparse_categorical_accuracy: 0.9069
# Epoch 33/75
# 428/428 - 67s - loss: 0.0301 - sparse_categorical_accuracy: 0.9905 - val_loss: 3.7567 - val_sparse_categorical_accuracy: 0.9168
# Epoch 34/75
# 428/428 - 67s - loss: 0.0304 - sparse_categorical_accuracy: 0.9904 - val_loss: 3.8675 - val_sparse_categorical_accuracy: 0.9090
# Epoch 35/75
# 428/428 - 67s - loss: 0.0265 - sparse_categorical_accuracy: 0.9920 - val_loss: 2.7713 - val_sparse_categorical_accuracy: 0.9144
# Epoch 36/75
# 428/428 - 66s - loss: 0.0292 - sparse_categorical_accuracy: 0.9906 - val_loss: 6.1691 - val_sparse_categorical_accuracy: 0.9182
# Epoch 37/75
# 428/428 - 67s - loss: 0.0256 - sparse_categorical_accuracy: 0.9919 - val_loss: 3.4300 - val_sparse_categorical_accuracy: 0.9107
# Epoch 38/75
# 428/428 - 67s - loss: 0.0297 - sparse_categorical_accuracy: 0.9907 - val_loss: 4.1480 - val_sparse_categorical_accuracy: 0.9075
# Epoch 39/75
# 428/428 - 68s - loss: 0.0289 - sparse_categorical_accuracy: 0.9910 - val_loss: 2.2425 - val_sparse_categorical_accuracy: 0.9130
# Epoch 40/75
# 428/428 - 67s - loss: 0.0262 - sparse_categorical_accuracy: 0.9917 - val_loss: 3.2135 - val_sparse_categorical_accuracy: 0.9162
# Epoch 41/75
# 428/428 - 67s - loss: 0.0239 - sparse_categorical_accuracy: 0.9924 - val_loss: 3.3811 - val_sparse_categorical_accuracy: 0.9103
# Epoch 42/75
# 428/428 - 67s - loss: 0.0267 - sparse_categorical_accuracy: 0.9919 - val_loss: 4.2861 - val_sparse_categorical_accuracy: 0.9104
# Epoch 43/75
# 428/428 - 67s - loss: 0.0264 - sparse_categorical_accuracy: 0.9917 - val_loss: 3.3401 - val_sparse_categorical_accuracy: 0.9122
# Epoch 44/75
# 428/428 - 66s - loss: 0.0285 - sparse_categorical_accuracy: 0.9916 - val_loss: 1.4365 - val_sparse_categorical_accuracy: 0.9051
# Epoch 45/75
# 428/428 - 68s - loss: 0.0236 - sparse_categorical_accuracy: 0.9931 - val_loss: 2.5372 - val_sparse_categorical_accuracy: 0.8906
# Epoch 46/75
# 428/428 - 67s - loss: 0.0232 - sparse_categorical_accuracy: 0.9929 - val_loss: 2.5481 - val_sparse_categorical_accuracy: 0.8897
# Epoch 47/75
# 428/428 - 67s - loss: 0.0253 - sparse_categorical_accuracy: 0.9919 - val_loss: 3.2592 - val_sparse_categorical_accuracy: 0.9066
# Epoch 48/75
# 428/428 - 68s - loss: 0.0261 - sparse_categorical_accuracy: 0.9922 - val_loss: 3.1488 - val_sparse_categorical_accuracy: 0.8938
# Epoch 49/75
# 428/428 - 68s - loss: 0.0242 - sparse_categorical_accuracy: 0.9929 - val_loss: 2.3809 - val_sparse_categorical_accuracy: 0.9223
# Epoch 50/75
# 428/428 - 68s - loss: 0.0243 - sparse_categorical_accuracy: 0.9923 - val_loss: 2.5474 - val_sparse_categorical_accuracy: 0.9004
# Epoch 51/75
# 428/428 - 67s - loss: 0.0245 - sparse_categorical_accuracy: 0.9922 - val_loss: 5.1048 - val_sparse_categorical_accuracy: 0.9036
# Epoch 52/75
# 428/428 - 67s - loss: 0.0250 - sparse_categorical_accuracy: 0.9926 - val_loss: 3.1153 - val_sparse_categorical_accuracy: 0.8958
# Epoch 53/75
# 428/428 - 68s - loss: 0.0219 - sparse_categorical_accuracy: 0.9933 - val_loss: 2.7121 - val_sparse_categorical_accuracy: 0.8878
# Epoch 54/75
# 428/428 - 67s - loss: 0.0210 - sparse_categorical_accuracy: 0.9935 - val_loss: 3.3301 - val_sparse_categorical_accuracy: 0.9073
# Epoch 55/75
# 428/428 - 66s - loss: 0.0214 - sparse_categorical_accuracy: 0.9937 - val_loss: 3.7533 - val_sparse_categorical_accuracy: 0.8890
# Epoch 56/75
# 428/428 - 67s - loss: 0.0221 - sparse_categorical_accuracy: 0.9931 - val_loss: 1.2079 - val_sparse_categorical_accuracy: 0.8937
# Epoch 57/75
# 428/428 - 68s - loss: 0.0210 - sparse_categorical_accuracy: 0.9938 - val_loss: 2.4531 - val_sparse_categorical_accuracy: 0.9190
# Epoch 58/75
# 428/428 - 67s - loss: 0.0236 - sparse_categorical_accuracy: 0.9928 - val_loss: 3.1403 - val_sparse_categorical_accuracy: 0.9021
# Epoch 59/75
# 428/428 - 67s - loss: 0.0233 - sparse_categorical_accuracy: 0.9933 - val_loss: 1.8601 - val_sparse_categorical_accuracy: 0.9086
# Epoch 60/75
# 428/428 - 68s - loss: 0.0179 - sparse_categorical_accuracy: 0.9944 - val_loss: 3.0911 - val_sparse_categorical_accuracy: 0.9239
# Epoch 61/75
# 428/428 - 67s - loss: 0.0223 - sparse_categorical_accuracy: 0.9934 - val_loss: 2.6516 - val_sparse_categorical_accuracy: 0.9158
# Epoch 62/75
# 428/428 - 67s - loss: 0.0199 - sparse_categorical_accuracy: 0.9937 - val_loss: 2.8989 - val_sparse_categorical_accuracy: 0.9245
# Epoch 63/75
# 428/428 - 66s - loss: 0.0225 - sparse_categorical_accuracy: 0.9930 - val_loss: 5.0858 - val_sparse_categorical_accuracy: 0.9180
# Epoch 64/75
# 428/428 - 67s - loss: 0.0200 - sparse_categorical_accuracy: 0.9938 - val_loss: 3.1285 - val_sparse_categorical_accuracy: 0.9140
# Epoch 65/75
# 428/428 - 67s - loss: 0.0172 - sparse_categorical_accuracy: 0.9945 - val_loss: 1.9675 - val_sparse_categorical_accuracy: 0.9194
# Epoch 66/75
# 428/428 - 66s - loss: 0.0214 - sparse_categorical_accuracy: 0.9935 - val_loss: 2.0798 - val_sparse_categorical_accuracy: 0.9084
# Epoch 67/75
# 428/428 - 66s - loss: 0.0220 - sparse_categorical_accuracy: 0.9929 - val_loss: 3.3433 - val_sparse_categorical_accuracy: 0.9131
# Epoch 68/75
# 428/428 - 67s - loss: 0.0192 - sparse_categorical_accuracy: 0.9943 - val_loss: 4.4042 - val_sparse_categorical_accuracy: 0.8925
# Epoch 69/75
# 428/428 - 67s - loss: 0.0228 - sparse_categorical_accuracy: 0.9931 - val_loss: 3.0950 - val_sparse_categorical_accuracy: 0.9141
# Epoch 70/75
# 428/428 - 40s - loss: 0.0181 - sparse_categorical_accuracy: 0.9942 - val_loss: 3.3301 - val_sparse_categorical_accuracy: 0.9160
# Epoch 71/75
# 428/428 - 30s - loss: 0.0182 - sparse_categorical_accuracy: 0.9945 - val_loss: 2.6646 - val_sparse_categorical_accuracy: 0.9138
# Epoch 72/75
# 428/428 - 30s - loss: 0.0211 - sparse_categorical_accuracy: 0.9940 - val_loss: 1.5597 - val_sparse_categorical_accuracy: 0.9025
# Epoch 73/75
# 428/428 - 30s - loss: 0.0175 - sparse_categorical_accuracy: 0.9946 - val_loss: 1.9797 - val_sparse_categorical_accuracy: 0.9203
# Time to fit model 4483.087469901
# 284/284 [==============================] - 11s 19ms/step
# Prediction Accuracy: 0.62060546875
# [[3217    1    0    0]
#  [ 144 2236  475 1175]
#  [   0 2027 2026  395]
#  [   2 2380  284 3790]]
#
#
#               precision    recall  f1-score   support
#
#            0      0.957     1.000     0.978      3218
#            1      0.337     0.555     0.419      4030
#            2      0.727     0.455     0.560      4448
#            3      0.707     0.587     0.642      6456
#
#     accuracy                          0.621     18152
#    macro avg      0.682     0.649     0.650     18152
# weighted avg      0.674     0.621     0.632     18152
#
#
#
# Total Time 4497.555139963
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-b19d54771cea> in <module>
#      31                                             Model_num = m_count,
#      32                                             segment_length = segment_length)
# ---> 33     append_list_time1 = append_list_time1.append(res_list, ignore_index=True)
#      34     Learning_Rate = 0.0125
#      35     Drop_rate = 0.3
#
# TypeError: append() missing 1 required positional argument: 'other'

# %%
tf.keras.backend.clear_session()
b_size = 512 #normally 2048 but 512 on colab
b_size2 = int(b_size / 4)
step_size = 300
step_length=step_size
segment_length = 2400
with mirrored_strategy.scope():
    train_dataset, test_dataset, y_s1 = Create_Batch(data_path, split_perc, segment_length, step_length, b_size)
waste_split = 0.1
with mirrored_strategy.scope():
    
    #Tuned Param dropout
    Learning_Rate = 0.0125
    Drop_rate = 0.175
    Repeats = 75

    m_count = 1
    print('Model Number %s' % m_count)
    history, y_preds, res_list = train_func(train_data=train_dataset,
                                            test_dataset=test_dataset,
                                            Val_dataset=val_dataset,
                                            predict_labels=predict_labels, 
                                            filt_num=16,
                                            kernel_num=11,
                                            dilation=7,
                                            stack=1,
                                            learn_r=Learning_Rate,
                                            drop_rate=Drop_rate,
                                            runs=Repeats,
                                            Model_num = m_count, 
                                            segment_length = segment_length)
    append_list_time1 = append_list_time1.append(res_list, ignore_index=True)
    Learning_Rate = 0.0125
    Drop_rate = 0.3
    Repeats = 75

    m_count = 2
    print('Model Number %s' % m_count)
    history, y_preds, res_list = train_func(train_data=train_dataset,
                                            test_dataset=test_dataset,
                                            Val_dataset=val_dataset,
                                            predict_labels=predict_labels, 
                                            filt_num=16,
                                            kernel_num=11,
                                            dilation=7,
                                            stack=1,
                                            learn_r=Learning_Rate,
                                            drop_rate=Drop_rate,
                                            runs=Repeats,
                                            Model_num = m_count, 
                                            segment_length = segment_length)

    append_list_time1 = append_list_time1.append(res_list, ignore_index=True)
    tf.keras.backend.clear_session()

# %%
tf.keras.backend.clear_session()
b_size = 1024 #normally 2048 but 512 on colab
b_size2 = int(b_size / 4)
step_size = 300
step_length=step_size
segment_length = 2400
with mirrored_strategy.scope():
    train_dataset, test_dataset, y_s1 = Create_Batch(data_path, split_perc, segment_length, step_length, b_size)
waste_split = 0.1
with mirrored_strategy.scope():
    
    #Tuned Param dropout
    Learning_Rate = 0.0125
    Drop_rate = 0.175
    Repeats = 75

    m_count = 1
    print('Model Number %s' % m_count)
    history, y_preds, res_list = train_func(train_data=train_dataset,
                                            test_dataset=test_dataset,
                                            Val_dataset=val_dataset,
                                            predict_labels=predict_labels, 
                                            filt_num=16,
                                            kernel_num=11,
                                            dilation=7,
                                            stack=1,
                                            learn_r=Learning_Rate,
                                            drop_rate=Drop_rate,
                                            runs=Repeats,
                                            Model_num = m_count, 
                                            segment_length = segment_length)
    append_list_time1 = append_list_time1.append(res_list, ignore_index=True)
    Learning_Rate = 0.0125
    Drop_rate = 0.3
    Repeats = 75

    m_count = 2
    print('Model Number %s' % m_count)
    history, y_preds, res_list = train_func(train_data=train_dataset,
                                            test_dataset=test_dataset,
                                            Val_dataset=val_dataset,
                                            predict_labels=predict_labels, 
                                            filt_num=16,
                                            kernel_num=11,
                                            dilation=7,
                                            stack=1,
                                            learn_r=Learning_Rate,
                                            drop_rate=Drop_rate,
                                            runs=Repeats,
                                            Model_num = m_count, 
                                            segment_length = segment_length)

    append_list_time1 = append_list_time1.append(res_list, ignore_index=True)
    tf.keras.backend.clear_session()

# %%
tf.keras.backend.clear_session()
b_size = 2048 #normally 2048 but 512 on colab
b_size2 = int(b_size / 4)
step_size = 300
step_length=step_size
segment_length = 2400
with mirrored_strategy.scope():
    train_dataset, test_dataset, y_s1 = Create_Batch(data_path, split_perc, segment_length, step_length, b_size)
waste_split = 0.1
with mirrored_strategy.scope():
    
    #Tuned Param dropout
    Learning_Rate = 0.0125
    Drop_rate = 0.175
    Repeats = 75

    print('Model Number %s' % m_count)
    history, y_preds, res_list = train_func(train_data=train_dataset,
                                            test_dataset=test_dataset,
                                            Val_dataset=val_dataset,
                                            predict_labels=predict_labels, 
                                            filt_num=16,
                                            kernel_num=11,
                                            dilation=7,
                                            stack=1,
                                            learn_r=Learning_Rate,
                                            drop_rate=Drop_rate,
                                            runs=Repeats,
                                            Model_num = m_count, 
                                            segment_length = segment_length)
    append_list_time1 = append_list_time1.append(res_list, ignore_index=True)
    Learning_Rate = 0.0125
    Drop_rate = 0.3
    Repeats = 75

    m_count = 2
    print('Model Number %s' % m_count)
    history, y_preds, res_list = train_func(train_data=train_dataset,
                                            test_dataset=test_dataset,
                                            Val_dataset=val_dataset,
                                            predict_labels=predict_labels, 
                                            filt_num=16,
                                            kernel_num=11,
                                            dilation=7,
                                            stack=1,
                                            learn_r=Learning_Rate,
                                            drop_rate=Drop_rate,
                                            runs=Repeats,
                                            Model_num = m_count, 
                                            segment_length = segment_length)

    append_list_time1 = append_list_time1.append(res_list, ignore_index=True)
    tf.keras.backend.clear_session()

# %% [markdown]
# # Batch Norm

# %%
append_list_time1.sort_values(by=['segment length', 'kernel size', 'stacks', 'dilation', 'filters'], ascending=[True, False, False, False, True])
append_list_time1.to_csv(r'{}.csv'.format('List_Check_300'), index = False, header=['segment length', 'filters', 'kernel size', 'stacks', 'dropout', 'lr', 'dilation','Training Time', 'train loss', 'train acc', 'eval acc','Eval Acc','C1 correct', 'C1 as C2', 'C1 as C3', 'C1 as C4','C2 as C1', 'C2 correct', 'C2 as C3', 'C2 as C4','C3 as C1', 'C3 as C2', 'C3 correct', 'C3 as C4','C4 as C1', 'C4 as C2', 'C4 as C3', 'C4 correct'])

# %%
append_list_time1

# %% [markdown]
# # Save and Reload Model
